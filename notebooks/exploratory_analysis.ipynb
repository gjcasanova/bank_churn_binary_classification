# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/raw/research/train.csv')

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115523 entries, 0 to 115522
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               115523 non-null  int64
#  1   CustomerId       115523 non-null  int64
#  2   Surname          115523 non-null  object
#  3   CreditScore      115523 non-null  int64
#  4   Geography        115523 non-null  object
#  5   Gender           115523 non-null  object
#  6   Age              115523 non-null  float64
#  7   Tenure           115523 non-null  int64
#  8   Balance          115523 non-null  float64
#  9   NumOfProducts    115523 non-null  int64
#  10  HasCrCard        115523 non-null  float64
#  11  IsActiveMember   115523 non-null  float64
#  12  EstimatedSalary  115523 non-null  float64
#  13  Exited           115523 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 12.3+ MB
# None

# %%
print(dataset['HasCrCard'].value_counts())
# Out:
# HasCrCard
# 1.0    87225
# 0.0    28298
# Name: count, dtype: int64

# %%
print(dataset.describe())
# Out:
#                   id    CustomerId    CreditScore            Age  \
# count  115523.000000  1.155230e+05  115523.000000  115523.000000
# mean    82447.502809  1.569212e+07     656.576526      38.126962
# std     47580.111429  7.145071e+04      80.156469       8.864176
# min         0.000000  1.556570e+07     350.000000      18.000000
# 25%     41364.500000  1.563306e+07     597.000000      32.000000
# 50%     82284.000000  1.569018e+07     659.000000      37.000000
# 75%    123681.500000  1.575690e+07     710.000000      42.000000
# max    165033.000000  1.581569e+07     850.000000      92.000000
#
#               Tenure        Balance  NumOfProducts      HasCrCard  \
# count  115523.000000  115523.000000  115523.000000  115523.000000
# mean        5.018438   55527.162784       1.553318       0.755044
# std         2.804606   62807.718399       0.547752       0.430063
# min         0.000000       0.000000       1.000000       0.000000
# ...

# %%
dataset.hist(bins=10, figsize=(20, 10))
plt.plot()
# Out:
# []
